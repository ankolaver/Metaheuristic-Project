# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Plot all of the Charging Stations
df = pd.read_csv("Unique_EVPts.csv")
plt.figure(figsize=(8, 6))
plt.scatter(df["Longitude"], df["Latitude"], color="red", marker="x")

# %%
# Sample from Delivery Locations

dl = pd.read_csv("DeliveryLocations.csv")

## choose 100 locations
todays_locations = dl.sample(n=100)
plt.figure(figsize=(8, 6))
plt.scatter(todays_locations["longitude"], todays_locations["latitude"], color="blue", marker=".")
# Fedex Ship Centre
plt.plot(104.0023106,1.3731437, color="green", marker="x")
